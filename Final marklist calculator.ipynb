# %%
from tkinter import*
r=Tk()
r.geometry("480x480")
r.configure(bg="yellow")
r.resizable(0,0)
r.title("Marklist")
def Calculate():
    Physics=na_entry.get()
    CHEMISTRY=na1_entry.get()
    MATHEMATICS=na2_entry.get()
    HINDI=na3_entry.get()
    ENGLISH=na4_entry.get()
    HISTORY=na5_entry.get()
    TOTAL=int(na_entry.get())+int(na1_entry.get())+int(na2_entry.get())+int(na3_entry.get())+int(na4_entry.get())+int(na5_entry.get())
    
    t1=Label(r,text=TOTAL,font=10)
    t1.place(x=180,y=320)
    TOTAL=int(na_entry.get())+int(na1_entry.get())+int(na2_entry.get())+int(na3_entry.get())+int(na4_entry.get())+int(na5_entry.get())
    Percentage=TOTAL/600*100
     
    t2=Label(r,text=Percentage,font=10)
    t2.place(x=180,y=360)
    
def clear():
    na_entry.delete(0,END)
    na1_entry.delete(0,END)
    na2_entry.delete(0,END)
    na3_entry.delete(0,END)
    na4_entry.delete(0,END)
    na5_entry.delete(0,END)
    na6_entry.delete(0,END)
    na7_entry.delete(0,END)
    
main=Label(r,text="FINAL RESULT",font=10)
main.place(x=180,y=25)
na=Label(r,text="Physics",font=10)
na.place(x=40,y=80)
na_entry=Entry(r,font=10)
na_entry.place(x=180,y=80)
na1=Label(r,text="CHEMISTRY",font=10)
na1.place(x=40,y=120)
na1_entry=Entry(r,font=10)
na1_entry.place(x=180,y=120)
na2=Label(r,text="MATHEMATICS",font=10)
na2.place(x=40,y=160)
na2_entry=Entry(r,font=10)
na2_entry.place(x=180,y=160)
na3=Label(r,text="HINDI",font=10)
na3.place(x=40,y=200)
na3_entry=Entry(r,font=10)
na3_entry.place(x=180,y=200)
na4=Label(r,text="ENGLISH",font=10)
na4.place(x=40,y=240)
na4_entry=Entry(r,font=10)
na4_entry.place(x=180,y=240)
na5=Label(r,text="HISTORY",font=10)
na5.place(x=40,y=280)
na5_entry=Entry(r,font=10)
na5_entry.place(x=180,y=280)
na6=Label(r,text="TOTAL",font=10)
na6.place(x=40,y=320)
na7=Label(r,text="Percentage",font=10)
na7.place(x=40,y=360)
button1=Button(r,text="Calculate",font=10,command=lambda: Calculate())
button1.place(x=40,y=420)
button2=Button(r,text="Clear",font=10,command=lambda:clear())
button2.place(x=240,y=420)
button3=Button(r,text="Next",font=10)
button3.place(x=400,y=420)

mainloop()
